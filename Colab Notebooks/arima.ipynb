# %%
# !pip install yfinance
#to import yahoo finance library, !magic command like r, pip is like a package

# %%
import yfinance as yf

# %%
# Import Data
df = yf.download("TSLA", start="2018-11-01", end="2020-11-01")

# %%
df.info()

# %%
df.head()

# %%
url= r'https://img1.wsimg.com/blobby/go/8c96521b-7ee0-4579-b983-c9c9fac1057e/downloads/Index2018.csv?ver=1605540124467'

# %%
import pandas as pd
file=pd.read_csv(url)

# %%
file.head()

# %%
file.info()

# %%
file=pd.read_csv(url,index_col='date', parse_dates=True)

# %%
file.info()

# %%
file.head()

# %%
# !pip install pmdarima

# %%
import pmdarima as pm
#import 3rd party

# %%
automodel = pm.auto_arima(file.spx, start_p=1, start_q=1, test="adf", seasonal=False, trace=True)
