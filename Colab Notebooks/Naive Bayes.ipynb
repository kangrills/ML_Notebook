# %%
from sklearn import datasets

# %%
X,y =datasets.load_iris(return_X_y=True)
#return just X and y differently

# %%
from sklearn.model_selection import train_test_split

# %%
# stratify means classes will have equal data
X_train, X_test, y_train, y_test= train_test_split(X,y,train_size=0.7, stratify=y,random_state=252)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model= GaussianNB()

# %%
model.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_pred))

# %%
confusion_matrix(y_test,y_pred)

# %%
# support means check data balancing
