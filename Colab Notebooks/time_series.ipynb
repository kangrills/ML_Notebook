# %%
#https://people.duke.edu/~rnau/411home.htm
# !pip install pmdarima
import pmdarima as pm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ts = pd.read_csv(r'https://img1.wsimg.com/blobby/go/8c96521b-7ee0-4579-b983-c9c9fac1057e/downloads/Index2018.csv?ver=1604887180395')

# %%
ts.head()

# %%
automodel = pm.auto_arima(ts.spx, start_p=1, start_q=1, test="adf", seasonal=False, trace=True)

# %%
print(automodel.summary())
