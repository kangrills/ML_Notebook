# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
URL=pd.read_csv(r'/content/Two Machines.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-80-9065f4c1f19f> in <module>()
# ----> 1 URL=pd.read_csv(r'/content/Two Machines.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
URL.describe()

# %%
URL.head()

# %%
URL.info()

# %%
m1 = URL[URL['Machine'] == 'Machine 1']['Volume']
m2 = URL[URL['Machine'] == 'Machine 2']['Volume']

# %%
m1

# %%
from statsmodels.stats import weightstats

# %%
import scipy.stats as stats

# %%
weightstats.ztest(m1, m2)

# %%
stats.ttest_ind(m1, m2, equal_var=True)

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()

# %%
tips.describe()

# %%
tm=tips[tips['sex']=='Male']['tip']

# %%
tf=tips[tips['sex']=='Female']['tip']

# %%
from statsmodels.stats import weightstats 
import scipy.stats as stats

# %% [markdown]
# Z TEST

# %%
weightstats.ztest(tf, tm)

# %% [markdown]
# T TEST

# %%
stats.ttest_ind(tf, tm, equal_var=True)

# %% [markdown]
# **CREATED** **LIST**

# %%
m1 = [150, 151, 152, 152, 151, 150]
m2 = [153, 152, 148, 151, 149, 152]
m3 = [156, 154, 155, 156, 157, 155]

# %%
from statsmodels.stats import oneway as oneway

# %% [markdown]
# F TEST

# %%
stats.f_oneway(m1, m2, m3)

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg

# %%
mpg.groupby('origin').mean()['mpg']

# %% [markdown]
# **ANOVA**

# %%
eu = mpg[(mpg['cylinders'] == 4) & (mpg['origin'] == 'europe')]['mpg']

# %%
jp = mpg[(mpg['cylinders'] == 4) & (mpg['origin'] == 'europe')]['mpg']

# %%
usa = mpg[(mpg['cylinders'] == 4) & (mpg['origin'] == 'europe')]['mpg']

# %%
eu

# %%
jp

# %%
usa

# %% [markdown]
# F TEST

# %%
import scipy.stats as stats

# %%
stats.f_oneway(eu,jp,usa)

# %%
url= r'https://img1.wsimg.com/blobby/go/8c96521b-7ee0-4579-b983-c9c9fac1057e/downloads/FuelEconomy.csv?ver=1609666327321'

# %%
URL=pd.read_csv(url)

# %%
URL.info()

# %%
y= URL['Fuel Economy']

# %%
y.shape

# %%
X= URL[['Horsepower']]

# %%
X.shape

# %%
from sklearn.linear_model import LinearRegression

# %%
regmodel = LinearRegression()

# %%
regmodel.fit(X,y)

# %%
regmodel.intercept_

# %%
regmodel.coef_

# %%
Fueleconomy= 39.23-0.072hp

# %%
#practice

# %%
url= r'https://img1.wsimg.com/blobby/go/8c96521b-7ee0-4579-b983-c9c9fac1057e/downloads/FuelEconomy.csv?ver=1609666327321'

# %%
URL=pd.read_csv(url)

# %%
URL.head()

# %%
URL.describe()

# %%
URL.info()

# %%
X=URL[["Horsepower"]]

# %%
X.shape
# Out:
# (100, 1)

# %%
y=URL["Fuel Economy"]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=123)

# %%
X_train
# Out:
#     Horsepower
# 21         233
# 90         238
# 33         283
# 69         316
# 84         225
# ..         ...
# 57         285
# 83         233
# 17         192
# 92         228
# 66         246
#
# [70 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# 39.21799410042862

# %%
model.coef_
# Out:
# array([-0.0725134])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([30.00879172, 22.97499148, 23.48258531, 32.54676088, 23.77263893,
#        30.58889896, 26.4556349 , 28.26847001, 21.08964296, 23.3375585 ,
#        28.99360406, 26.02055447, 23.62761212, 22.46739765, 21.52472339,
#        21.52472339, 15.94119124, 28.1234432 , 20.94461615, 23.19253169,
#        17.31894592, 24.42525957, 29.28365768, 30.51638555, 26.4556349 ,
#        24.28023276, 21.88729041, 27.32579575, 21.01712956, 26.67317511])

# %%
y_pred.shape
# Out:
# (30,)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 1.0162497749316688

# %% [markdown]
# #Problem 2

# %%
Url=r"https://img1.wsimg.com/blobby/go/8c96521b-7ee0-4579-b983-c9c9fac1057e/downloads/SAT%20GPA.csv?ver=1610864531937"

# %%
import pandas as pd

# %%
df1=pd.read_csv(Url)

# %%
df1.head()
# Out:
#     SAT  GPA
# 0  1270  3.4
# 1  1220  4.0
# 2  1160  3.8
# 3   950  3.8
# 4  1070  4.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SAT     1000 non-null   int64
#  1   GPA     1000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 15.8 KB

# %%
df1.describe()
# Out:
#                SAT          GPA
# count  1000.000000  1000.000000
# mean   1033.290000     3.203700
# std     142.873681     0.542541
# min     530.000000     1.800000
# 25%     930.000000     2.800000
# 50%    1030.000000     3.200000
# 75%    1130.000000     3.700000
# max    1440.000000     4.500000

# %%
X=df1[["SAT"]]

# %%
X.shape
# Out:
# (1000, 1)

# %%
y=df1["GPA"]

# %%
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 123)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([0.00163826])

# %%
lr.intercept_
# Out:
# 1.5240905555052968

# %%
#GPA=1.52+0.0016SAT+error

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.2335021086958436

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.39522269161675877
