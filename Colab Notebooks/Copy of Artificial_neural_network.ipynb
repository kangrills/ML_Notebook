# %%
import pandas as pd

# %%
df=pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Default%20Dummy%20Data.csv')

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
X=df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']]
X.shape
#X=df.drop('diabetes',axis=1)

# %%
y=df['default']

# %%
X.shape, y.shape

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc.fit(X)

# %%
X=sc.transform(X)

# %%
#X=sc.fit_transform(X) can also be used
X

# %%
from keras.models import Sequential
from keras.layers import Dense
model= Sequential()
# sequential for every layer write each line of code
#for dense connection each neurons are connected to previous all neuron
model.add(Dense(9, input_dim=8, activation="relu"))
#9 is for 8 feature + bias, only in first line initialize input_dim= 8 features for no of features
model.add(Dense(12, activation ='relu'))
# 12 depends on you for no of neurons
model.add(Dense(14, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# for binary decison at the last need only 1 neuron binary always use sigmoid

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])
# for backward propogation loss is error to be calculated using  binary problem binary_crossentropy
# optimizer to minimize error using Gradient descent function or adam

# %%
model.summary()

# %%
# 398 weights need to be calculated, therefore need more data. As data is not that large so solution is EPOCHS

# %%
model.fit(X,y,epochs=100, batch_size=100)
# epochs: no of times data move in a loop
# optimizer will run only after 100 batch size

# %%
score=model.evaluate(X,y,verbose=0)
print(score)
# loss and accuracy

# %%
y_pred=model.predict(X)

# %%
y_pred[:10]

# %%
import numpy as np

# %%
y_pred=y_pred.round()
#round float to integer 0,1

# %%
y_pred

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y,y_pred)

# %%
print(classification_report(y,y_pred))

# %%
# for precision and recall used confusion matrix
