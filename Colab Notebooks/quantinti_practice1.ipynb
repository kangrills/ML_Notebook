# %%
import pandas as pd

# %%
data=pd.read_csv("TCS.NS.csv",index_col="Date",parse_dates=True)

# %%
data.shape

# %%
data.head()

# %%
data.tail()

# %%
data.index

# %%
data.columns

# %%
data.values

# %%
type(data)

# %%
type(data.values)

# %%
data2=data.copy()

# %%
import matplotlib.pyplot as plt

# %%
data['Close'].plot()
