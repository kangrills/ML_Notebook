# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"https://github.com/Yantra-Byte/Dataset/raw/main/Admission%20Chance.csv")

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
df.tail()

# %%
df.columns

# %%
X=df[['GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
       'LOR ', 'CGPA', 'Research']]

# %%
X

# %%
X.shape

# %%
y=df['Chance of Admit ']

# %%
y

# %%
y.shape

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3, random_state=252)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)

# %%
lr.coef_

# %%
lr.intercept_
