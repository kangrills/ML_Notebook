# %%
import pandas as pd

# %%
# df=pd.read_csv(r"C:\Users\acer\Desktop\Boston (1).csv")

# %%
df=pd.read_csv(r'/content/Boston (1).csv')

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
df.columns

# %%
X=df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]
X.shape

# %%
y=df['MEDV']
y.shape

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression

# %%
# KNN Regression 
from sklearn.neighbors import KNeighborsRegressor

# %%
# Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor

# %%
#
from sklearn.svm import SVR

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import train_test_split
#shift enter to go to new code

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.3, random_state=252)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)

# %%
y_pred= model.predict(X_test)

# %%
y_pred

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test,y_pred)

# %%
mean_squared_error(y_test,y_pred)
